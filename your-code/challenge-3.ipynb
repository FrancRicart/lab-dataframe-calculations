# %% [markdown]
# # Challenge 3
#
# In this challenge we will work on the `Orders` data set. In your work you will apply the thinking process and workflow we showed you in Challenge 2.
#
# You are serving as a Business Intelligence Analyst at the headquarter of an international fashion goods chain store. Your boss today asked you to do two things for her:
#
# **First, identify two groups of customers from the data set.** The first group is **VIP Customers** whose **aggregated expenses** at your global chain stores are **above the 95th percentile** (aka. 0.95 quantile). The second group is **Preferred Customers** whose **aggregated expenses** are **between the 75th and 95th percentile**.
#
# **Second, identify which country has the most of your VIP customers, and which country has the most of your VIP+Preferred Customers combined.**

# %% [markdown]
# ## Q1: How to identify VIP & Preferred Customers?
#
# We start by importing all the required libraries:

# %%
# import required libraries
import numpy as np
import pandas as pd

# %% [markdown]
# Next, extract and import `Orders` dataset into a dataframe variable called `orders`. Print the head of `orders` to overview the data:

# %%
orders = pd.read_csv('orders.zip')
orders = orders.drop(columns=orders.columns[0])
orders
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 0          536365    85123A  2010     12    3     8
# 1          536365     71053  2010     12    3     8
# 2          536365    84406B  2010     12    3     8
# 3          536365    84029G  2010     12    3     8
# 4          536365    84029E  2010     12    3     8
# ...           ...       ...   ...    ...  ...   ...
# 397919     581587     22613  2011     12    5    12
# 397920     581587     22899  2011     12    5    12
# 397921     581587     23254  2011     12    5    12
# 397922     581587     23255  2011     12    5    12
# 397923     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                       white metal lantern         6  2010-12-01 08:26:00
# 2            cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# ...

# %% [markdown]
# ---
#
# "Identify VIP and Preferred Customers" is the non-technical goal of your boss. You need to translate that goal into technical languages that data analysts use:
#
# ## How to label customers whose aggregated `amount_spent` is in a given quantile range?

# %% [markdown]
# We break down the main problem into several sub problems:
#
# #### Sub Problem 1: How to aggregate the  `amount_spent` for unique customers?
#
# #### Sub Problem 2: How to select customers whose aggregated `amount_spent` is in a given quantile range?
#
# #### Sub Problem 3: How to label selected customers as "VIP" or "Preferred"?
#
# *Note: If you want to break down the main problem in a different way, please feel free to revise the sub problems above.*
#
# Now in the workspace below, tackle each of the sub problems using the iterative problem solving workflow. Insert cells as necessary to write your codes and explain your steps.

# %%
# Aggregating the 'amount_spent' for Customers and Country using 'groupby'

customer_spent = orders.groupby(["CustomerID"]).agg({"amount_spent":sum}).reset_index()
customer_spent
# Out:
#       CustomerID  amount_spent
# 0          12346      77183.60
# 1          12347       4310.00
# 2          12348       1797.24
# 3          12349       1757.55
# 4          12350        334.40
# ...          ...           ...
# 4334       18280        180.60
# 4335       18281         80.82
# 4336       18282        178.05
# 4337       18283       2094.88
# 4338       18287       1837.28
#
# [4339 rows x 2 columns]

# %%
vip = customer_spent[customer_spent["amount_spent"] > customer_spent["amount_spent"].quantile(0.95)]
preferred = customer_spent[(customer_spent["amount_spent"] < customer_spent["amount_spent"].quantile(0.95)) & (customer_spent["amount_spent"] < customer_spent["amount_spent"].quantile(0.75))]

# %%
vip["Group"]="VIP"
vip
# Out:
# /var/folders/_k/1xyh1kms5gg3dls55pm6gkwr0000gn/T/ipykernel_31354/2600847215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vip["Group"]="VIP"
#       CustomerID  amount_spent Group
# 0          12346      77183.60   VIP
# 10         12357       6207.67   VIP
# 12         12359       6372.58   VIP
# 50         12409      11072.67   VIP
# 55         12415     124914.53   VIP
# ...          ...           ...   ...
# 4207       18109       8052.97   VIP
# 4229       18139       8438.34   VIP
# 4253       18172       7561.68   VIP
# 4292       18223       6484.54   VIP
# 4298       18229       7276.90   VIP
#
# [217 rows x 3 columns]

# %%
preferred["Group"] = "preferred"
preferred
# Out:
# /var/folders/_k/1xyh1kms5gg3dls55pm6gkwr0000gn/T/ipykernel_31354/1460034437.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preferred["Group"] = "preferred"
#       CustomerID  amount_spent      Group
# 4          12350        334.40  preferred
# 6          12353         89.00  preferred
# 7          12354       1079.40  preferred
# 8          12355        459.40  preferred
# 11         12358       1168.06  preferred
# ...          ...           ...        ...
# 4332       18277        110.38  preferred
# 4333       18278        173.90  preferred
# 4334       18280        180.60  preferred
# 4335       18281         80.82  preferred
# 4336       18282        178.05  preferred
#
# [3254 rows x 3 columns]

# %%
groups = pd.concat([vip, preferred], axis = 0)
groups
# Out:
#       CustomerID  amount_spent      Group
# 0          12346      77183.60        VIP
# 10         12357       6207.67        VIP
# 12         12359       6372.58        VIP
# 50         12409      11072.67        VIP
# 55         12415     124914.53        VIP
# ...          ...           ...        ...
# 4332       18277        110.38  preferred
# 4333       18278        173.90  preferred
# 4334       18280        180.60  preferred
# 4335       18281         80.82  preferred
# 4336       18282        178.05  preferred
#
# [3471 rows x 3 columns]

# %%
orders = pd.merge(left = orders,
                  right = groups,
                  how = "left",
                  left_on = "CustomerID",
                  right_on = "CustomerID")

orders
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 0          536365    85123A  2010     12    3     8
# 1          536365     71053  2010     12    3     8
# 2          536365    84406B  2010     12    3     8
# 3          536365    84029G  2010     12    3     8
# 4          536365    84029E  2010     12    3     8
# ...           ...       ...   ...    ...  ...   ...
# 397919     581587     22613  2011     12    5    12
# 397920     581587     22899  2011     12    5    12
# 397921     581587     23254  2011     12    5    12
# 397922     581587     23255  2011     12    5    12
# 397923     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                       white metal lantern         6  2010-12-01 08:26:00
# 2            cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# ...

# %%
#Last, but not least, we will define the rest of the clients as "regular"

orders["Group"] = orders["Group"].fillna("regular")

# %%
#And see how it finally ends

orders["Group"].value_counts()
# Out:
# regular      151781
# preferred    141659
# VIP          104484
# Name: Group, dtype: int64

# %% [markdown]
# Now we'll leave it to you to solve Q2 & Q3, which you can leverage from your solution for Q1:
#
# ## Q2: How to identify which country has the most VIP Customers?

# %%
vip_orders = orders[orders["Group"]=="VIP"]
vip_orders
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 26         536370     22728  2010     12    3     8
# 27         536370     22727  2010     12    3     8
# 28         536370     22726  2010     12    3     8
# 29         536370     21724  2010     12    3     8
# 30         536370     21883  2010     12    3     8
# ...           ...       ...   ...    ...  ...   ...
# 397883     581584     85038  2011     12    5    12
# 397905     581586     22061  2011     12    5    12
# 397906     581586     23275  2011     12    5    12
# 397907     581586     21217  2011     12    5    12
# 397908     581586     20685  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 26                alarm clock bakelike pink        24  2010-12-01 08:45:00
# 27                alarm clock bakelike red         24  2010-12-01 08:45:00
# 28               alarm clock bakelike green        12  2010-12-01 08:45:00
# ...

# %%
vip_orders_count = vip_orders.groupby(["Country"]).agg({"CustomerID":pd.Series.nunique}).reset_index()
vip_orders_count
# Out:
#             Country  CustomerID
# 0         Australia           2
# 1           Belgium           1
# 2   Channel Islands           1
# 3            Cyprus           1
# 4           Denmark           1
# 5              EIRE           2
# 6           Finland           1
# 7            France           9
# 8           Germany          10
# 9             Japan           2
# 10      Netherlands           1
# 11           Norway           1
# 12         Portugal           2
# 13        Singapore           1
# 14            Spain           2
# 15           Sweden           1
# 16      Switzerland           3
# 17   United Kingdom         177

# %%
vip_orders_count[vip_orders_count["CustomerID"] == vip_orders_count["CustomerID"].max()]
vip_orders_count
# Out:
#             Country  CustomerID
# 0         Australia           2
# 1           Belgium           1
# 2   Channel Islands           1
# 3            Cyprus           1
# 4           Denmark           1
# 5              EIRE           2
# 6           Finland           1
# 7            France           9
# 8           Germany          10
# 9             Japan           2
# 10      Netherlands           1
# 11           Norway           1
# 12         Portugal           2
# 13        Singapore           1
# 14            Spain           2
# 15           Sweden           1
# 16      Switzerland           3
# 17   United Kingdom         177

# %% [markdown]
# ## Q3: How to identify which country has the most VIP+Preferred Customers combined?

# %%
top_orders = orders[(orders["Group"] == "VIP") | (orders["Group"] == "preferred")]
top_orders
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 26         536370     22728  2010     12    3     8
# 27         536370     22727  2010     12    3     8
# 28         536370     22726  2010     12    3     8
# 29         536370     21724  2010     12    3     8
# 30         536370     21883  2010     12    3     8
# ...           ...       ...   ...    ...  ...   ...
# 397919     581587     22613  2011     12    5    12
# 397920     581587     22899  2011     12    5    12
# 397921     581587     23254  2011     12    5    12
# 397922     581587     23255  2011     12    5    12
# 397923     581587     22138  2011     12    5    12
#
#                             Description  Quantity          InvoiceDate  \
# 26            alarm clock bakelike pink        24  2010-12-01 08:45:00
# 27            alarm clock bakelike red         24  2010-12-01 08:45:00
# 28           alarm clock bakelike green        12  2010-12-01 08:45:00
# ...

# %%
top_orders_count = top_orders.groupby(["Country"]).agg({"CustomerID":pd.Series.nunique}).reset_index()
top_orders_count
# Out:
#                  Country  CustomerID
# 0              Australia           7
# 1                Austria           8
# 2                Bahrain           2
# 3                Belgium          14
# 4                 Brazil           1
# 5                 Canada           3
# 6        Channel Islands           6
# 7                 Cyprus           5
# 8         Czech Republic           1
# 9                Denmark           7
# 10                  EIRE           2
# 11    European Community           1
# 12               Finland           8
# 13                France          67
# 14               Germany          65
# 15                Greece           3
# 16                Israel           1
# 17                 Italy           9
# 18                 Japan           6
# 19             Lithuania           1
# 20                 Malta           1
# 21           Netherlands           9
# 22                Norway           4
# 23                Poland           5
# ...

# %%
top_orders_count[top_orders_count["CustomerID"] == top_orders_count["CustomerID"].max()]
# Out:
#            Country  CustomerID
# 33  United Kingdom        3166
